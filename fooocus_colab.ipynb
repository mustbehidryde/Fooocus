# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/mustbehidryde/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 43.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6534, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6534 (delta 1), reused 1 (delta 1), pack-reused 6530 (from 2)
# Receiving objects: 100% (6534/6534), 33.24 MiB | 22.24 MiB/s, done.
# Resolving deltas: 100% (3718/3718), done.
# /content/Fooocus

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 9.69MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 8.59MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 85.1MB/s]
# ...

# %%
# !tar -cvf images.tar /content/Fooocus/outputs/2025-05-07
# Out:
# tar: Removing leading `/' from member names
# /content/Fooocus/outputs/2025-05-07/
# /content/Fooocus/outputs/2025-05-07/2025-05-07_13-24-26_6283.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_14-07-11_4487.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_13-49-58_7590.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_13-43-34_8926.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_13-18-08_1496.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_14-23-58_4530.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_14-13-54_2680.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_14-00-17_4987.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_13-15-50_1652.png
# /content/Fooocus/outputs/2025-05-07/log.html
# /content/Fooocus/outputs/2025-05-07/2025-05-07_13-20-08_3094.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_14-21-39_3448.png
# /content/Fooocus/outputs/2025-05-07/2025-05-07_13-47-53_3938.png
# ...
